# %%
import pandas as pd
import json

# %%
url = '/Users/mac/Downloads/yelp_dataset/'
data = pd.read_json(url + 'business.json', lines=True)
#data.loc[data['city'] == 'Guadalajara']
#data.loc[data['categories'] == 'Hotels']
#data['categories'].value_counts()
restaurants_filter = data[data['categories'].str.contains("Strip") == True]
restaurants_filter.sort_values(['review_count'], ascending=False)
#data.loc[data['name'] == 'Palomino Club']
# Out:
#                                 address  \
# 7184              3850 Las Vegas Blvd S
# 25925               6007 Dean Martin Dr
# 124480                 3000 Paradise Rd
# 95882                 3525 W Russell Rd
# 92864             1848 Las Vegas Blvd N
# 44530                  2801 Westwood Dr
# 69562                  1514 Western Ave
# 51850   3663 S Las Vegas Blvd, Ste 360G
# 22                  6007 Dean Martin Dr
# 15114      3663 S Las Vegas Blvd, #360F
# 123107                 2901 E Thomas Rd
# 162119                   4716 N 12th St
# 151779                 1258 Rue Stanley
# 74788                2580 S Highland Dr
# 15843             1818 N Las Vegas Blvd
# 75529               910 N Mcclintock Dr
# 170405             5151 E Washington St
# 181051      1171 Rue Sainte-Catherine E
# 128481                       135 9th St
# 21556                  4420 E Thomas Rd
# 38645         94 Rue Sainte-Catherine E
# 173633   1800 S Industrial Rd, Ste 206C
# ...

# %%
# !curl ifconfig.me
# Out:
# 148.241.109.145
